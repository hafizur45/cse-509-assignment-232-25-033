# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizur45/cse-509-assignment-232-25-033/blob/main/cse_509_assignment_232_25_033.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import neccesary libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **Connected colab with google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Read data set**

# %%
df=pd.read_csv('/content/drive/MyDrive/Datasets/Mental-illnesses.csv')

# %%
df.head()
# Out:
#         Entity Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  Afghanistan  AFG  1990                  0.223206              4.996118
# 1  Afghanistan  AFG  1991                  0.222454              4.989290
# 2  Afghanistan  AFG  1992                  0.221751              4.981346
# 3  Afghanistan  AFG  1993                  0.220987              4.976958
# 4  Afghanistan  AFG  1994                  0.220183              4.977782
#
#    Anxiety disorders
# 0            4.713314
# 1            4.702100
# 2            4.683743
# 3            4.673549
# 4            4.670810

# %%
df.head()
# Out:
#         Entity Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  Afghanistan  AFG  1990                  0.223206              4.996118
# 1  Afghanistan  AFG  1991                  0.222454              4.989290
# 2  Afghanistan  AFG  1992                  0.221751              4.981346
# 3  Afghanistan  AFG  1993                  0.220987              4.976958
# 4  Afghanistan  AFG  1994                  0.220183              4.977782
#
#    Anxiety disorders
# 0            4.713314
# 1            4.702100
# 2            4.683743
# 3            4.673549
# 4            4.670810

# %%
df.Entity.nunique()
# Out:
# 214

# %%
df.Code.nunique()
# Out:
# 205

# %%
df.shape
# Out:
# (6420, 6)

# %% [markdown]
# check null values

# %%
df.isnull().sum()
# Out:
# Entity                        0
# Code                        270
# Year                          0
# Schizophrenia disorders       0
# Depressive disorders          0
# Anxiety disorders             0
# dtype: int64

# %% [markdown]
# # **Handling** **null values using mode**

# %%
# Replace missing values in 'column_name' with the mode
df['Code'].fillna(df['Code'].mode()[0], inplace=True)

# %%
df1=df.copy()
df2=df.copy()
df3=df.copy()

# %%
df.isnull().sum()
# Out:
# Entity                      0
# Code                        0
# Year                        0
# Schizophrenia disorders     0
# Depressive disorders        0
# Anxiety disorders           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6420 entries, 0 to 6419
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Entity                    6420 non-null   object
#  1   Code                      6420 non-null   object
#  2   Year                      6420 non-null   int64
#  3   Schizophrenia disorders   6420 non-null   float64
#  4   Depressive disorders      6420 non-null   float64
#  5   Anxiety disorders         6420 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 301.1+ KB

# %% [markdown]
# # **Apply label encoder for categorical column**

# %%
from sklearn.preprocessing import LabelEncoder as le

# %%
l=le()

# %%
#for col in df.columns:
  #if col!=np.number:
    #df[col]=l.fit_transform(df[col])

# %%
df.head()
# Out:
#         Entity Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  Afghanistan  AFG  1990                  0.223206              4.996118
# 1  Afghanistan  AFG  1991                  0.222454              4.989290
# 2  Afghanistan  AFG  1992                  0.221751              4.981346
# 3  Afghanistan  AFG  1993                  0.220987              4.976958
# 4  Afghanistan  AFG  1994                  0.220183              4.977782
#
#    Anxiety disorders
# 0            4.713314
# 1            4.702100
# 2            4.683743
# 3            4.673549
# 4            4.670810

# %%
df['Entity'] = l.fit_transform(df.Entity)

# %%
df['Code'] = l.fit_transform(df.Code)

# %%
df.head()
# Out:
#    Entity  Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0       0     0  1990                  0.223206              4.996118
# 1       0     0  1991                  0.222454              4.989290
# 2       0     0  1992                  0.221751              4.981346
# 3       0     0  1993                  0.220987              4.976958
# 4       0     0  1994                  0.220183              4.977782
#
#    Anxiety disorders
# 0            4.713314
# 1            4.702100
# 2            4.683743
# 3            4.673549
# 4            4.670810

# %%
df1.isnull().sum()
# Out:
# Entity                      0
# Code                        0
# Year                        0
# Schizophrenia disorders     0
# Depressive disorders        0
# Anxiety disorders           0
# dtype: int64

# %% [markdown]
# # **Apply one hot encoding**

# %%
from sklearn.preprocessing import OneHotEncoder as oe

# %%
o=oe()

# %%
dummies = pd.get_dummies(df1['Entity'])

# %%
dummies
# Out:
#       Afghanistan  Africa (IHME GBD)  Albania  Algeria  America (IHME GBD)  \
# 0            True              False    False    False               False
# 1            True              False    False    False               False
# 2            True              False    False    False               False
# 3            True              False    False    False               False
# 4            True              False    False    False               False
# ...           ...                ...      ...      ...                 ...
# 6415        False              False    False    False               False
# 6416        False              False    False    False               False
# 6417        False              False    False    False               False
# 6418        False              False    False    False               False
# 6419        False              False    False    False               False
#
# ...

# %%
df1.drop('Entity',axis=1,inplace=True)

# %%
df1=pd.concat((df1,dummies),axis=1)

# %%
df1.head()
# Out:
#   Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  AFG  1990                  0.223206              4.996118
# 1  AFG  1991                  0.222454              4.989290
# 2  AFG  1992                  0.221751              4.981346
# 3  AFG  1993                  0.220987              4.976958
# 4  AFG  1994                  0.220183              4.977782
#
#    Anxiety disorders   Afghanistan  Africa (IHME GBD)  Albania  Algeria  \
# 0            4.713314         True              False    False    False
# 1            4.702100         True              False    False    False
# 2            4.683743         True              False    False    False
# 3            4.673549         True              False    False    False
# 4            4.670810         True              False    False    False
#
#    America (IHME GBD)  ...  Upper-middle-income countries  Uruguay  \
# 0               False  ...                          False    False
# ...

# %%
dummies2 = pd.get_dummies(df1['Code'])

# %%
dummies2
# Out:
#         AFG    AGO    ALB    AND    ARE    ARG    ARM    ASM    ATG    AUS  \
# 0      True  False  False  False  False  False  False  False  False  False
# 1      True  False  False  False  False  False  False  False  False  False
# 2      True  False  False  False  False  False  False  False  False  False
# 3      True  False  False  False  False  False  False  False  False  False
# 4      True  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6415  False  False  False  False  False  False  False  False  False  False
# 6416  False  False  False  False  False  False  False  False  False  False
# 6417  False  False  False  False  False  False  False  False  False  False
# 6418  False  False  False  False  False  False  False  False  False  False
# 6419  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
df1=pd.concat((df1,dummies2),axis=1)

# %%
df1.head()
# Out:
#   Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  AFG  1990                  0.223206              4.996118
# 1  AFG  1991                  0.222454              4.989290
# 2  AFG  1992                  0.221751              4.981346
# 3  AFG  1993                  0.220987              4.976958
# 4  AFG  1994                  0.220183              4.977782
#
#    Anxiety disorders   Afghanistan  Africa (IHME GBD)  Albania  Algeria  \
# 0            4.713314         True              False    False    False
# 1            4.702100         True              False    False    False
# 2            4.683743         True              False    False    False
# 3            4.673549         True              False    False    False
# 4            4.670810         True              False    False    False
#
#    America (IHME GBD)  ...    VCT    VEN    VIR    VNM    VUT    WSM    YEM  \
# 0               False  ...  False  False  False  False  False  False  False
# ...

# %% [markdown]
# # **apply mapping**

# %%
df4=df3.copy()
df5=df3.copy()

# %%
mapping_dict = {}

# %%
for index,category in enumerate(df3['Entity'].unique()):
  mapping_dict[category] = index

# %%
df3['entity_mapped'] = df3['Entity'].map(mapping_dict)

# %%
df3.head()
# Out:
#         Entity Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  Afghanistan  AFG  1990                  0.223206              4.996118
# 1  Afghanistan  AFG  1991                  0.222454              4.989290
# 2  Afghanistan  AFG  1992                  0.221751              4.981346
# 3  Afghanistan  AFG  1993                  0.220987              4.976958
# 4  Afghanistan  AFG  1994                  0.220183              4.977782
#
#    Anxiety disorders   entity_mapped
# 0            4.713314              0
# 1            4.702100              0
# 2            4.683743              0
# 3            4.673549              0
# 4            4.670810              0

# %%
mapping_dict.clear()
for index,category in enumerate(df3['Code'].unique()):
  mapping_dict[category] = index
df3['Code_mapped'] = df3['Code'].map(mapping_dict)

# %%
df3.head()
# Out:
#         Entity Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  Afghanistan  AFG  1990                  0.223206              4.996118
# 1  Afghanistan  AFG  1991                  0.222454              4.989290
# 2  Afghanistan  AFG  1992                  0.221751              4.981346
# 3  Afghanistan  AFG  1993                  0.220987              4.976958
# 4  Afghanistan  AFG  1994                  0.220183              4.977782
#
#    Anxiety disorders   entity_mapped  Code_mapped
# 0            4.713314              0            0
# 1            4.702100              0            0
# 2            4.683743              0            0
# 3            4.673549              0            0
# 4            4.670810              0            0

# %% [markdown]
# # **Scaling**

# %%
df1.head()
# Out:
#   Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  AFG  1990                  0.223206              4.996118
# 1  AFG  1991                  0.222454              4.989290
# 2  AFG  1992                  0.221751              4.981346
# 3  AFG  1993                  0.220987              4.976958
# 4  AFG  1994                  0.220183              4.977782
#
#    Anxiety disorders   Afghanistan  Africa (IHME GBD)  Albania  Algeria  \
# 0            4.713314         True              False    False    False
# 1            4.702100         True              False    False    False
# 2            4.683743         True              False    False    False
# 3            4.673549         True              False    False    False
# 4            4.670810         True              False    False    False
#
#    America (IHME GBD)  ...    VCT    VEN    VIR    VNM    VUT    WSM    YEM  \
# 0               False  ...  False  False  False  False  False  False  False
# ...

# %%
df2.head()
# Out:
#         Entity Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  Afghanistan  AFG  1990                  0.223206              4.996118
# 1  Afghanistan  AFG  1991                  0.222454              4.989290
# 2  Afghanistan  AFG  1992                  0.221751              4.981346
# 3  Afghanistan  AFG  1993                  0.220987              4.976958
# 4  Afghanistan  AFG  1994                  0.220183              4.977782
#
#    Anxiety disorders
# 0            4.713314
# 1            4.702100
# 2            4.683743
# 3            4.673549
# 4            4.670810

# %%
df.head()
# Out:
#    Entity  Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0       0     0  1990                  0.223206              4.996118
# 1       0     0  1991                  0.222454              4.989290
# 2       0     0  1992                  0.221751              4.981346
# 3       0     0  1993                  0.220987              4.976958
# 4       0     0  1994                  0.220183              4.977782
#
#    Anxiety disorders
# 0            4.713314
# 1            4.702100
# 2            4.683743
# 3            4.673549
# 4            4.670810

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6420 entries, 0 to 6419
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Entity                    6420 non-null   int64
#  1   Code                      6420 non-null   int64
#  2   Year                      6420 non-null   int64
#  3   Schizophrenia disorders   6420 non-null   float64
#  4   Depressive disorders      6420 non-null   float64
#  5   Anxiety disorders         6420 non-null   float64
# dtypes: float64(3), int64(3)
# memory usage: 301.1 KB

# %% [markdown]
# # **Apply Robust Scaler using loop for floating point  numeric column where apply label encoding**

# %%
from sklearn.preprocessing import RobustScaler

# Assuming 'df' is your DataFrame

# List of numeric columns
numeric_cols = df.select_dtypes(include=['float64']).columns

# Initialize RobustScaler
scaler = RobustScaler()

# Loop through each numeric column and scale it
for col in numeric_cols:
    df[col] = scaler.fit_transform(df[[col]])

# Now df contains scaled values

# %%
df.head()
# Out:
#    Entity  Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0       0     0  1990                 -1.134605              1.056857
# 1       0     0  1991                 -1.151577              1.051548
# 2       0     0  1992                 -1.167434              1.045372
# 3       0     0  1993                 -1.184676              1.041960
# 4       0     0  1994                 -1.202827              1.042601
#
#    Anxiety disorders
# 0            0.679745
# 1            0.669894
# 2            0.653767
# 3            0.644812
# 4            0.642406

# %% [markdown]
# # **apply Standard scaler using loop for floating point numeric column where apply onehot encoding**

# %%
from sklearn.preprocessing import StandardScaler

# Assuming 'df' is your DataFrame

# List of numeric columns
numeric_cols = df1.select_dtypes(include=['float64']).columns

# Initialize StandardScaler
scaler = StandardScaler()

# Loop through each numeric column and scale it
for col in numeric_cols:
    df1[col] = scaler.fit_transform(df1[[col]])
    print(col)

# Now df contains scaled values
# Out:
# Schizophrenia disorders
# Depressive disorders
# Anxiety disorders

# %%
df1.head()
# Out:
#   Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  AFG  1990                 -1.102046              1.328430
# 1  AFG  1991                 -1.121143              1.321050
# 2  AFG  1992                 -1.138983              1.312464
# 3  AFG  1993                 -1.158383              1.307722
# 4  AFG  1994                 -1.178805              1.308612
#
#    Anxiety disorders   Afghanistan  Africa (IHME GBD)  Albania  Algeria  \
# 0            0.582101         True              False    False    False
# 1            0.571425         True              False    False    False
# 2            0.553950         True              False    False    False
# 3            0.544246         True              False    False    False
# 4            0.541639         True              False    False    False
#
#    America (IHME GBD)  ...    VCT    VEN    VIR    VNM    VUT    WSM    YEM  \
# 0               False  ...  False  False  False  False  False  False  False
# ...

# %% [markdown]
# # **apply MinMax Scaler using loop for floating point numeric column where apply mapping**

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming 'df' is your DataFrame

# List of numeric columns
numeric_cols = df3.select_dtypes(include=['float64']).columns

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Loop through each numeric column and scale it
for col in numeric_cols:
    df3[col] = scaler.fit_transform(df3[[col]])
    print(col)


# Now df contains scaled values using min-max normalization


# Now df contains scaled values
# Out:
# Schizophrenia disorders
# Depressive disorders
# Anxiety disorders

# %%
df3.head()
# Out:
#         Entity Code  Year  Schizophrenia disorders   Depressive disorders  \
# 0  Afghanistan  AFG  1990                  0.127142              0.567281
# 1  Afghanistan  AFG  1991                  0.124394              0.566166
# 2  Afghanistan  AFG  1992                  0.121826              0.564869
# 3  Afghanistan  AFG  1993                  0.119034              0.564153
# 4  Afghanistan  AFG  1994                  0.116095              0.564287
#
#    Anxiety disorders   entity_mapped  Code_mapped
# 0            0.420084              0            0
# 1            0.418422              0            0
# 2            0.415700              0            0
# 3            0.414189              0            0
# 4            0.413783              0            0
